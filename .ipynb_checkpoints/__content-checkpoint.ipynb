# %% [markdown]
# # <code>**- Intro**</code>
#     - Machine learning
#     - Supervised learning
#         - Regression and classification
#     - Unsupervised learning
#         - Clusterization, cluster analysis
#         - Anomaly detection
#         - Dimensionality reduction
#
# # <code>**- Linear Regression**</code>
#     - Introduction to "Line of best fit"
#     - Univariate regression (linear regression with 1 variable)
#     - Cost function (mean square error)
#     - Gradient descent
#     - Multivariate regression (linear regression with many variables)
#     - Feature Scaling
#     - Features and polynomial regression
#     - Computing parameters analytically (Normal equation)
#     - Polynomial model implementation I
#     - Polynomial model implementation II
#     - Metrics: RMSE, MAE, MSE, MAPE, MPE overview
#     - Regularization
#     - Stock price prediction model I
#     - Stock price prediction model II
#
#
#
# # <code>**- Logistic Regression**</code>
#     - Introduction to clasification problems
#     - Logistic regression (sigmoid function)
#     - Cost function (Maximum likelihood estimation)
#     - Gradient descent
#     - Binary clasification
#     - Metrics: Confusion matrix, accuracy, precision, recall, F1 score
#     - Multiclass classification:
#         • One vs Rest (OvR)
#         • One vs One  (OvO)
#     - Regularization
#         • Ridge
#         • Lasso
#         • Elastic net
#     - Advanced optimizations
#     - Advanced multiclass classification exercise, MNIST handwritten digit database
#     - Metrics: ROC-AUC
#     - Stock price prediction - classification model I
#     - Stock price prediction - classification model II
#
#     - Instanced based classification
#        • KNN, K-Nearest Neighbor Classification Algorithm
#
# # <code>**- Artificial Neural Networks**</code>
#     - Introduction to non-linear hypothesis
#     - NN (Perceptron) model representation
#     - Logical Unit and network
#     - Forward propagation
#     - Cost function
#     - Back propagation
#     - Multiclass classification
#     - Optimizations techniques
#       • Unrolling parameters
#       • Gradient probing/checking
#       • Random Initialization
#     - Network architecture:
#       • RBF
#       • Hopfield
#
#     - Application
#       • ?? Stock trading agent I
#       • ?? Stock trading agent II
#       • ?? Robotics
#
# # <code>**- Support vector machine (SVM)**</code>
#      - Objective
#      - Large margin
#      - Kernels
#
# # <code>**- Clustering**</code>
#      - Objective
#      - K-Means
#      - Hierarchical clustering
#
# # <code>**- Dimensionality Reduction**</code>
#      - Data compression
#      - Principal Component Analysis
#      - Reconstrcution from compressed space
#
# # <code>**- Large Scale Machine Learning**</code>
#
#
# # <code>**- Prerequisites**</code>
#     - Python
#     - Numpy
#     - Matplotlib
#     - Pandas
#     - Linear algebra and statistics basics
