# %% [markdown]
# ## Confusion matrix
#
# It present a table layout of the different outcomes of prediction and result of a classification problem and hels visualize its outcomes. It helps us identify the correct predictions of a model for different individual classes as well as the errors.
#
# ![confusion_matrix.jpg](attachment:confusion_matrix.jpg)
#
# Lets say we are working on medical field, and we are talking about cancer diagnosis. On prediction we want <code>**0 False negatives**</code> If we have 5% false positives and 5% false negatives it would be better to have 20% false positives and 0 false negatives.  The same might be applied to a task for autonomous driving, well we don't want any false positives because it might be a direction toward cliff.
#
# Confusion matrix metris are performance measures which help us find the accuracy of our classifier. <br>
# <code>**There are 4 main metrics:**</code>

# %% [markdown]
# ## Accuracy
#
# The accuracy is used to find the portion of correctly classified values. <code>**It tells us how often our classifier is right**</code>. It is the ratio difference between model's all values and actual values <code>**t / ( tp + tn)**</code>
# \begin{multline*}
# \text{accuracy}(y, \hat{y}) = \dfrac{1}{n} \sum_{i=0}^{n-1} 1(\hat{y}_{i} = y_{i})
# \end{multline*}
#
# ![confusion_matrix_case_a.jpg](attachment:confusion_matrix_case_a.jpg)
#
# <code>**1) Classifier metrics:**</code>
#    * Accuracy = 0.8125
#
# <code>**2) Classifier metrics:**</code>
#    * Accuracy = 0.781
# ________________

# %% [markdown]
# ## Precision
#
# The precision is used to calculate model's ability to classify positive values correctly. It answers the question. <code>**When the model predicts a positive value, how iften it is right ?**</code>
# It is the ratio <code>**tp / (tp + fp)**</code> where tp is the number of true positives and fp the number of false positives. The precision is intuitively the ability of the classifier to not label a sample as positive if it is negative.<br>
#
# ![confusion_matrix_case_c.jpg](attachment:confusion_matrix_case_c.jpg)
#
# <code>**1) Classifier metrics:**</code>
#    * Precision = 0.89
#
# <code>**2) Classifier metrics:**</code>
#    * Precision = 0.85
#
#  ________________

# %% [markdown]
# ## Recall
#
# It is used to calculate the models ability to predict positive values. How often does the model actually predict the correct positive values.
# The recall is the ratio <code>**tp / (tp + fn)**</code> where tp is the number of true positives and fn the number of false negatives. The recall is intuitively the ability of the classifier to find all the positive samples.
#
# ![confusion_matrix_case_b.jpg](attachment:confusion_matrix_case_b.jpg)
#
# <code>**1) Classifier metrics:**</code>
#    * Recall = 0.82
#
# <code>**2) Classifier metrics:**</code>
#    * Recall = 0.80
# ________________

# %% [markdown]
# <div class="alert alert-block alert-success">
#
# <h2>Practice exercise</h2>
# <p>Calculate <code>recall measure</code> for classification example below:</p>
# </div>

# %% [markdown]
# ![dog_classification.jpg](attachment:dog_classification.jpg)

# %% [markdown]
# ## F1 score
#
# This score provides a way to combine both precision and recall into a single measure that captures both properties. A harmonic mean that gives a overall perfomance score for our model.
# So It is the harmonic mean of recall and precision.<code>**It is usefull when you need to take both precision and recall into account**</code>.
# The F-beta score can be interpreted as a weighted harmonic mean of the precision and recall, where an F-beta score reaches <code>**its best value at 1 and worst score at 0**</code>. The F-beta score weights the recall more than the precision by a factor of beta. beta = 1.0 means recall and precision are equally important. <code>**2 * (precision * recall) / (precision + recall)**</code>
#
# _________________

# %%
acc = 17/20
print(f'accuracy: {acc}')
pre = 8/10
print(f'precision: {pre}')
rec = 8/9
print(f'recall: {rec}')
f1  = (2*pre*rec)/(pre+rec)
print(f'f1 score: {f1}')
# Out:
# accuracy: 0.85
# precision: 0.8
# recall: 0.8888888888888888
# f1 score: 0.8421052631578948

# %%
def accuracy(y_true, y_pred):
    return np.sum(y_true == y_pred) / len(y_true)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# %%
print(f'accuracy score:{accuracy(y_test.flatten(), y_pred)}\n')
print('SKLEARN metrics modules')
print(f'accuracy:{accuracy_score(y_test, y_pred)}')
print(f'precision:{precision_score(y_test, y_pred)}')
print(f'recall:{recall_score(y_test, y_pred)}')
print(f'f1_score:{recall_score(y_test, y_pred)}')

# %%
print(cm)

# %%
y_pred

# %%
y_test.flatten()

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

# %% [markdown]
# ## Plot
#
# ### 2D
#
# \begin{multline*}
# h_{\theta}(x) = \theta_{0} + \theta_{1}x_{1} + \theta_{2}x_{2}
# \end{multline*}
# ______________________________
# \begin{multline*}
# h_{\theta}(x) = \theta^{\top}x
# \end{multline*}
# ______________________________
# \begin{multline*}
# x_{2} = - \dfrac{\theta_{0} + \theta_{1}x_{1}}{\theta_{2}}
# \end{multline*}

# %%
np.min(X[:, 1])
np.max(X[:, 2])
θ = θ.flatten()

xmin = np.min(X[:, 1] - 10)
xmax = np.max(X[:, 2] + 10)

x_values = [xmin, xmax]
y_values = - (θ[0] + np.dot(θ[1], x_values)) / θ[2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4314cd35fc6a> in <module>
# ----> 1 np.min(X[:, 1])
#       2 np.max(X[:, 2])
#       3 θ = θ.flatten()
#       4
#       5 xmin = np.min(X[:, 1] - 10)
#
# NameError: name 'np' is not defined

# %%
plt.figure(figsize=(12,8))
plt.scatter(X[:, 1], X[:, 2], c=y, s=40, alpha=0.65);
plt.plot(x_values, y_values, ls='--', label='decision boundary')
plt.fill_between(x_values, y_values, xmin, color='blue', alpha=0.2)
plt.fill_between(x_values, y_values, xmax, color='orange', alpha=0.2)
plt.xlabel(r'$x_1$',fontsize=22)
plt.ylabel(r'$x_2$',fontsize=22)
plt.legend()
plt.show()

# %% [markdown]
# ### 3D

# %%
##TODO

# %%
# %matplotlib notebook
# x_space = np.linspace(-5,5,10)
# y_space = np.linspace(-5,5,10)
# x_points, y_points = np.meshgrid(x_space, y_space)
# z_points = (d - a*x_points - b*y_points) / c


# fig = plt.figure(figsize=(6, 6))
# ax = Axes3D(fig)
# ax.set_facecolor('#ffff')
# ax.scatter(X[:, 0], X[:, 1], X[:,2], c=y);
# #ax.plot_surface(x_points, y_points, z_points, alpha=0.4)
# ax.view_init(30, 60)
# plt.show()
