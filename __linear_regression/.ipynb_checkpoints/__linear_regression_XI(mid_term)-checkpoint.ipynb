# %% [markdown]
# pip install pandas-datareader
# pip install yfinance

# %%
import os
import numpy as np
import pandas as pd 
import datetime as dt
import matplotlib.pyplot as plt
plt.style.use('bmh')

# %%
from pandas_datareader import data as pdr
import yfinance as yfin

yfin.pdr_override()

# %%
# %matplotlib inline

# %%
#ACN
#TSLA

# %%
def merge_df_by_column_name(col_name, sdate, edate, df):
    mask = (df['Date'] >= sdate) & (df['Date'] <= edate)
    fragment = df.loc[mask][col_name]
    return fragment

# %%
def data_to_path(ticker, base_dir='../data_samples/stocks/'):
    return os.path.join(base_dir, '{}.csv'.format(ticker))

# %%
def save_to_csv(ticker, syear, smonth, sday, eyear, emonth, eday):
    start = dt.datetime(syear, smonth, sday)
    end   = dt.datetime(eyear, emonth, eday)
    
    df = pdr.get_data_yahoo(ticker, start, end)
    df.to_csv(data_to_path(ticker))
    return df

# %%
frame = save_to_csv('ETH-USD', 2020, 1, 1, 2021, 12, 20)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
frame
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-31   132.612274   133.732681   128.798157   129.610855   129.610855
# 2020-01-01   129.630661   132.835358   129.198288   130.802002   130.802002
# 2020-01-02   130.820038   130.820038   126.954910   127.410179   127.410179
# 2020-01-03   127.411263   134.554016   126.490021   134.171707   134.171707
# 2020-01-04   134.168518   136.052719   133.040558   135.069366   135.069366
# ...                 ...          ...          ...          ...          ...
# 2021-12-15  3862.251465  4086.372803  3664.719971  4018.388672  4018.388672
# 2021-12-16  4020.415039  4110.368652  3956.057129  3962.469727  3962.469727
# 2021-12-17  3959.012451  3992.792480  3711.424561  3879.486572  3879.486572
# 2021-12-18  3880.291504  3993.829834  3774.614990  3960.860107  3960.860107
# 2021-12-19  3960.872314  4018.658447  3894.398682  3922.592529  3922.592529
#
#                  Volume
# Date
# 2019-12-31   8936866397
# 2020-01-01   7935230330
# 2020-01-02   8032709256
# 2020-01-03  10476845358
# 2020-01-04   7430904515
# ...                 ...
# 2021-12-15  26411188833
# 2021-12-16  19825531254
# 2021-12-17  23143541098
# 2021-12-18  19530895889
# 2021-12-19  16167785597
#
# [720 rows x 6 columns]

# %%
def simple_plot(data, name, x_label, y_label):
    plt.figure(figsize=(18,6))
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.title(name)
    plt.plot(data)
    plt.show()

# %%
simple_plot(
    frame['Adj Close'], 
    'ETH tick  2020/1/1 - 2021/12/20', 
    'Days', 
    'Adj Close price $'
)

# %%
frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 720 entries, 2019-12-31 to 2021-12-19
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       720 non-null    float64
#  1   High       720 non-null    float64
#  2   Low        720 non-null    float64
#  3   Close      720 non-null    float64
#  4   Adj Close  720 non-null    float64
#  5   Volume     720 non-null    int64
# dtypes: float64(5), int64(1)
# memory usage: 39.4 KB

# %%
frame.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# <code>**daily_return[t] = (price[t] / price[t-1]) - 1**</code>

# %%
def add_daily_return_and_volatily(df):
    df['daily_returns'] = (df['Adj Close'] / df['Adj Close'].shift(1)) - 1
    df['volatily'] = ((df['High'] - df['Low']) / df['Low']) * 100
    df.fillna(0, inplace=True)

# %%
add_daily_return_and_volatily(frame)

# %%
# 1.797

# %%
frame
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2019-12-31   132.612274   133.732681   128.798157   129.610855   129.610855
# 2020-01-01   129.630661   132.835358   129.198288   130.802002   130.802002
# 2020-01-02   130.820038   130.820038   126.954910   127.410179   127.410179
# 2020-01-03   127.411263   134.554016   126.490021   134.171707   134.171707
# 2020-01-04   134.168518   136.052719   133.040558   135.069366   135.069366
# ...                 ...          ...          ...          ...          ...
# 2021-12-15  3862.251465  4086.372803  3664.719971  4018.388672  4018.388672
# 2021-12-16  4020.415039  4110.368652  3956.057129  3962.469727  3962.469727
# 2021-12-17  3959.012451  3992.792480  3711.424561  3879.486572  3879.486572
# 2021-12-18  3880.291504  3993.829834  3774.614990  3960.860107  3960.860107
# 2021-12-19  3960.872314  4018.658447  3894.398682  3922.592529  3922.592529
#
#                  Volume  daily_returns   volatily
# Date
# 2019-12-31   8936866397       0.000000   3.831207
# 2020-01-01   7935230330       0.009190   2.815107
# 2020-01-02   8032709256      -0.025931   3.044488
# 2020-01-03  10476845358       0.053069   6.375203
# 2020-01-04   7430904515       0.006690   2.264092
# ...                 ...            ...        ...
# 2021-12-15  26411188833       0.072875  11.505731
# 2021-12-16  19825531254      -0.013916   3.900639
# 2021-12-17  23143541098      -0.020942   7.581130
# 2021-12-18  19530895889       0.020975   5.807608
# 2021-12-19  16167785597      -0.009661   3.190730
#
# [720 rows x 8 columns]

# %%
data = frame[['Adj Close', 'Volume', 'daily_returns', 'volatily']]

# %%
data
# Out:
#               Adj Close       Volume  daily_returns   volatily
# Date
# 2019-12-31   129.610855   8936866397       0.000000   3.831207
# 2020-01-01   130.802002   7935230330       0.009190   2.815107
# 2020-01-02   127.410179   8032709256      -0.025931   3.044488
# 2020-01-03   134.171707  10476845358       0.053069   6.375203
# 2020-01-04   135.069366   7430904515       0.006690   2.264092
# ...                 ...          ...            ...        ...
# 2021-12-15  4018.388672  26411188833       0.072875  11.505731
# 2021-12-16  3962.469727  19825531254      -0.013916   3.900639
# 2021-12-17  3879.486572  23143541098      -0.020942   7.581130
# 2021-12-18  3960.860107  19530895889       0.020975   5.807608
# 2021-12-19  3922.592529  16167785597      -0.009661   3.190730
#
# [720 rows x 4 columns]

# %%
X = np.array(data.drop(['Adj Close'], 1))

# %%
x_00 = X[:,0]
x_01 = X[:,1]
x_02 = X[:,2]

# %%
x_00_mean = np.mean(x_00)
x_01_mean = np.mean(x_01)
x_02_mean = np.mean(x_02)
print(
    f' x_00 mean: {x_00_mean}\n',
    f'x_01 mean:  {x_01_mean}\n',
    f'x_02 mean:  {x_02_mean}',
)
# Out:
#  x_00 mean: 20838763479.77778
#  x_01 mean:  0.006200730522985633
#  x_02 mean:  7.469788832833567

# %%
space = np.linspace(0, x_00.size,int( x_00.size))

# %%
fig, ax = plt.subplots(3, figsize=(18, 12))
ax[0].scatter(space, x_00 ,c='b')
ax[0].set_title('Volume')
ax[0].axhline(np.mean(x_00), color='r', linestyle='dashed')
ax[1].scatter(space, x_01, c='g')
ax[1].set_title('Daily returns')
ax[1].axhline(np.mean(x_01), color='r', linestyle='dashed')
ax[2].scatter(space, x_02, c='r')
ax[2].set_title('Volatily')
ax[2].axhline(np.mean(x_02), color='r', linestyle='dashed')
plt.show()

# %%
y = np.array(data['Adj Close'])

# %%
y = np.reshape(y,(-1, 1))

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import scale

# %%
X_normalized = scale(X)

# %%
print(X_normalized.mean(axis=0))
print(X_normalized.std(axis=0))
# Out:
# [-3.94745964e-17 -1.97372982e-17  9.86864911e-17]
# [1. 1. 1.]

# %%
x_0 = X_normalized[:,0]
x_1 = X_normalized[:,1]
x_2 = X_normalized[:,2]

# %%
x_0_mean = np.mean(x_0)
x_1_mean = np.mean(x_1)
x_2_mean = np.mean(x_2)
print(
    f' x_0 mean: {x_0_mean}\n',
    f'x_1 mean: {x_1_mean}\n',
    f'x_2 mean: {x_2_mean}',
)
# Out:
#  x_0 mean: -3.947459643111668e-17
#  x_1 mean: -1.973729821555834e-17
#  x_2 mean: 9.868649107779169e-17

# %%
space = np.linspace(0, x_0.size,int( x_0.size))

# %%
fig, ax = plt.subplots(3, figsize=(18, 12))
ax[0].scatter(space, x_0 ,c='b')
ax[0].axhline(np.mean(x_0), color='r', linestyle='dashed')
ax[1].scatter(space, x_1, c='g')
ax[1].axhline(np.mean(x_1), color='r', linestyle='dashed')
ax[2].scatter(space, x_2, c='r')
ax[2].axhline(np.mean(x_2), color='r', linestyle='dashed')
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True)

# %%
X[0]
# Out:
# array([8.93686640e+09, 0.00000000e+00, 3.83120742e+00])

# %%
X_train[0]
# Out:
# array([ 1.83449301e+10, -6.03548619e-03,  3.86225184e+00])

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print(f"θ's: {model.coef_}")
print(f"θ0: {model.intercept_}")
# Out:
# θ's: [[ 6.66602319e-08 -5.10595878e+02 -5.16085854e+01]]
# θ0: [532.69162202]

# %%
model.score(X_test, y_test)
# Out:
# 0.321988661943054

# %%
model.score(X_train, y_train)
# Out:
# 0.18269162980989762

# %%
y_prediction = model.predict(X_test)

# %%
test_days = int(len(frame) * .2)
test_days
# Out:
# 144

# %%
# Out:
# Date
# 2021-12-17    3879.486572
# 2021-12-18    3960.860107
# 2021-12-19    3922.592529
# Name: Adj Close, dtype: float64

# %%
from sklearn.metrics import mean_squared_error

# %%
mse_b = mean_squared_error(y_test, y_prediction)
mse_b
# Out:
# 51628.10913198264

# %%
data.shape
# Out:
# (497, 4)

# %%
simple_plot(data['Adj Close'][397:], 'ETH-USD', 'datos', 'kainos')
